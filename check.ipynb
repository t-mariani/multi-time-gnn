# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Goal of this notebook
#
# Visual checks that our pipeline is working fine
# The idea is that we shoudl have a visual check at several steps of the pipeline:
# * batch extraction
# * model prediction
# * loss computation
# * ...

# %%
from multi_time_gnn.dataset import get_batch, read_dataset
from multi_time_gnn.visualization import plot_batch

clipN = 5
dataset = read_dataset("solar")
dataset = dataset[:,:clipN]
xt, yt = get_batch(4, dataset, 168)
plot_batch(xt, yt, show=False);
